# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("/home/jc/Escritorio/Proyectos_finales_ironhack/ih_datamadpt0420_project_m2/diamonds_train.csv")

# %% [markdown]
# ### Features
# - id: only for test & sample submission files, id for prediction sample identification
# - price: price in USD
# - carat: weight of the diamond
# - cut: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# - color: diamond colour, from J (worst) to D (best)
# - clarity: a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# - x: length in mm
# - y: width in mm
# - z: depth in mm
# - depth: total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# - table: width of top of diamond relative to widest point (43--95)

# %%
data.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
data.describe(include='all')
# Out:
#                carat    cut  color clarity         depth         table  \
# count   40455.000000  40455  40455   40455  40455.000000  40455.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  16220   8455    9749           NaN           NaN
# mean        0.797706    NaN    NaN     NaN     61.752841     57.446133
# std         0.475544    NaN    NaN     NaN      1.431725      2.233535
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         4.500000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# ...

# %%
data.max()
# Out:
# carat            4.5
# cut        Very Good
# color              J
# clarity         VVS2
# depth             79
# table             95
# price          18823
# x              10.23
# y               58.9
# z               8.06
# dtype: object

# %%
print(f'Max price row:' ,data.price.idxmax())  #max price
#print the max price row
data[7034:7035]
# Out:
# Max price row: 7034
#       carat      cut color clarity  depth  table  price    x     y     z
# 7034   2.29  Premium     I     VS2   60.8   60.0  18823  8.5  8.47  5.16

# %%
print(f'Min price row:' ,data.price.idxmin()) 
#print the min price row
data[9782:9783]
# Out:
# Min price row: 9782
#       carat    cut color clarity  depth  table  price     x     y     z
# 9782   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43

# %%
print(f'standard deviation:' , data.std())
# Out:
# standard deviation: carat       0.475544
# depth       1.431725
# table       2.233535
# price    3992.416147
# x           1.124453
# y           1.146650
# z           0.697062
# dtype: float64

# %%
print(f'median:' , data.median())
# Out:
# median: carat       0.70
# depth      61.80
# table      57.00
# price    2397.00
# x           5.69
# y           5.71
# z           3.52
# dtype: float64

# %%
print(f'mean:' , data.mean())
# Out:
# mean: carat       0.797706
# depth      61.752841
# table      57.446133
# price    3928.444469
# x           5.729392
# y           5.732819
# z           3.537154
# dtype: float64

# %% [markdown]
# ### Visualisation

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('svg')

# %matplotlib inline

# %%
plt.scatter(x = )

# %%
data.plot(kind='hist' , figsize=(10,6) , alpha = 0.5);

# %%
#data.hist(figsize = (10,4))

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
# pandas + seaborn ---> 

#objetivo de fondo es conocer el dataset, relevancia ---> informe. Quieres que no te tonguen , entender cómo funciona. Correlación.
# ciertos rangos pueden tener distintos precios


#tableau sea más dashboard ---> principio del dashboard= usabilidad, sacar conlusiones. ---> orientado: ¿Cómo varia mi precio según caracteristicas? ---> herramienta de consulta visual
